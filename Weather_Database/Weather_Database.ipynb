# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
                # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | otuzco
# Processing Record 9 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 1 | dzerzhinsk
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | srednekolymsk
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | lavrentiya
# Processing Record 20 of Set 1 | anadyr
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | barra velha
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | nerchinskiy zavod
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | aklavik
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | oktyabrskoye
# Processing Record 32 of Set 1 | magnolia
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | kaeo
# Processing Record 40 of Set 1 | komyshuvakha
# Processing Record 41 of Set 1 | missoula
# Processing Record 42 of Set 1 | pahalgam
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | katsuura
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | matara
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | laguna
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | abu dhabi
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | kalmunai
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | cabinda
# Processing Record 9 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | kargasok
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | saint-francois
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | takoradi
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | lagoa
# Processing Record 22 of Set 2 | rocha
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | siachoque
# Processing Record 27 of Set 2 | akhaldaba
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | nata
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | bonavista
# Processing Record 32 of Set 2 | roebourne
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | buraydah
# Processing Record 35 of Set 2 | tautira
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | viedma
# Processing Record 39 of Set 2 | lukovetskiy
# Processing Record 40 of Set 2 | santa isabel do rio negro
# Processing Record 41 of Set 2 | esperance
# Processing Record 42 of Set 2 | pinhao
# Processing Record 43 of Set 2 | coihaique
# Processing Record 44 of Set 2 | sinnamary
# Processing Record 45 of Set 2 | sumbe
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | eyl
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | vung tau
# Processing Record 50 of Set 2 | tromso
# Processing Record 1 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | bais
# Processing Record 6 of Set 3 | havoysund
# Processing Record 7 of Set 3 | magdagachi
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | the valley
# Processing Record 10 of Set 3 | rawson
# Processing Record 11 of Set 3 | kamenka
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | zaranj
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | vicuna
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | kismayo
# Processing Record 19 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 3 | palkaka
# City not found. Skipping...
# Processing Record 21 of Set 3 | mehran
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 3 | mayo
# Processing Record 24 of Set 3 | aktas
# Processing Record 25 of Set 3 | harqalah
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 28 of Set 3 | watertown
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | alice springs
# Processing Record 33 of Set 3 | bengkulu
# Processing Record 34 of Set 3 | vostok
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | sitka
# Processing Record 38 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | angoram
# Processing Record 41 of Set 3 | coro
# Processing Record 42 of Set 3 | teknaf
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | brokopondo
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | hambantota
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | saint-augustin
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 4 | praia
# Processing Record 2 of Set 4 | razole
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | dingle
# Processing Record 6 of Set 4 | mujiayingzi
# Processing Record 7 of Set 4 | ishinomaki
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | anage
# Processing Record 10 of Set 4 | scituate
# Processing Record 11 of Set 4 | guadalupe y calvo
# Processing Record 12 of Set 4 | kimbe
# Processing Record 13 of Set 4 | okato
# Processing Record 14 of Set 4 | fortuna
# Processing Record 15 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | yichun
# Processing Record 18 of Set 4 | sambava
# Processing Record 19 of Set 4 | teguise
# Processing Record 20 of Set 4 | hofn
# Processing Record 21 of Set 4 | port antonio
# Processing Record 22 of Set 4 | catuday
# Processing Record 23 of Set 4 | san cristobal
# Processing Record 24 of Set 4 | ponta delgada
# Processing Record 25 of Set 4 | khandyga
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | tarut
# Processing Record 28 of Set 4 | amga
# Processing Record 29 of Set 4 | kenai
# Processing Record 30 of Set 4 | mecca
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | teguldet
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | hithadhoo
# Processing Record 35 of Set 4 | porto santo
# Processing Record 36 of Set 4 | puerto leguizamo
# Processing Record 37 of Set 4 | vryburg
# Processing Record 38 of Set 4 | milkovo
# Processing Record 39 of Set 4 | whitianga
# Processing Record 40 of Set 4 | xuddur
# Processing Record 41 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 4 | dakar
# Processing Record 43 of Set 4 | iqaluit
# Processing Record 44 of Set 4 | maldonado
# Processing Record 45 of Set 4 | pangoa
# Processing Record 46 of Set 4 | cuenca
# Processing Record 47 of Set 4 | likasi
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | mahon
# Processing Record 50 of Set 4 | novyy svit
# Processing Record 1 of Set 5 | ahipara
# Processing Record 2 of Set 5 | kiunga
# Processing Record 3 of Set 5 | houston
# Processing Record 4 of Set 5 | changtu
# Processing Record 5 of Set 5 | svetlaya
# Processing Record 6 of Set 5 | fort walton beach
# Processing Record 7 of Set 5 | jumla
# Processing Record 8 of Set 5 | donskoye
# Processing Record 9 of Set 5 | praxedis guerrero
# Processing Record 10 of Set 5 | ust-tsilma
# Processing Record 11 of Set 5 | sabaudia
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | yerbogachen
# Processing Record 14 of Set 5 | tezu
# Processing Record 15 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | hearst
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | deputatskiy
# Processing Record 20 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | luderitz
# Processing Record 24 of Set 5 | pringsewu
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 5 | davidson
# Processing Record 28 of Set 5 | brigantine
# Processing Record 29 of Set 5 | pong
# Processing Record 30 of Set 5 | san juan de los morros
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | grindavik
# Processing Record 33 of Set 5 | ulaangom
# Processing Record 34 of Set 5 | tambopata
# Processing Record 35 of Set 5 | safaga
# Processing Record 36 of Set 5 | saint-leu
# Processing Record 37 of Set 5 | ambunti
# Processing Record 38 of Set 5 | brunico
# Processing Record 39 of Set 5 | charters towers
# Processing Record 40 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | tagusao
# Processing Record 43 of Set 5 | mattawa
# Processing Record 44 of Set 5 | mount isa
# Processing Record 45 of Set 5 | chipinge
# Processing Record 46 of Set 5 | tondano
# Processing Record 47 of Set 5 | barabash
# Processing Record 48 of Set 5 | hobyo
# Processing Record 49 of Set 5 | khilok
# Processing Record 50 of Set 5 | khatanga
# Processing Record 1 of Set 6 | yulara
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | jalingo
# Processing Record 4 of Set 6 | tshane
# Processing Record 5 of Set 6 | karratha
# Processing Record 6 of Set 6 | krasnozerskoye
# Processing Record 7 of Set 6 | acarau
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | eureka
# Processing Record 10 of Set 6 | liverpool
# Processing Record 11 of Set 6 | byron bay
# Processing Record 12 of Set 6 | artvin
# Processing Record 13 of Set 6 | belyy yar
# Processing Record 14 of Set 6 | malatya
# Processing Record 15 of Set 6 | sulangan
# Processing Record 16 of Set 6 | bolzano
# Processing Record 17 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 6 | barao de melgaco
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | kitakata
# Processing Record 21 of Set 6 | itarema
# Processing Record 22 of Set 6 | laela
# Processing Record 23 of Set 6 | mount gambier
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | isla vista
# Processing Record 26 of Set 6 | kruisfontein
# Processing Record 27 of Set 6 | filadelfia
# Processing Record 28 of Set 6 | schattdorf
# Processing Record 29 of Set 6 | marzuq
# Processing Record 30 of Set 6 | hopelchen
# Processing Record 31 of Set 6 | urengoy
# Processing Record 32 of Set 6 | karatau
# Processing Record 33 of Set 6 | upington
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | shuangyang
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | boa vista
# Processing Record 40 of Set 6 | manzanillo
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | imisli
# City not found. Skipping...
# Processing Record 43 of Set 6 | vyshneve
# Processing Record 44 of Set 6 | imbituba
# Processing Record 45 of Set 6 | leh
# Processing Record 46 of Set 6 | chuy
# Processing Record 47 of Set 6 | tres arroyos
# Processing Record 48 of Set 6 | sao joao evangelista
# Processing Record 49 of Set 6 | kurchum
# Processing Record 50 of Set 6 | volkermarkt
# City not found. Skipping...
# Processing Record 1 of Set 7 | kanjiza
# Processing Record 2 of Set 7 | kassala
# Processing Record 3 of Set 7 | yago
# Processing Record 4 of Set 7 | high level
# Processing Record 5 of Set 7 | san vicente
# Processing Record 6 of Set 7 | havre-saint-pierre
# Processing Record 7 of Set 7 | zambezi
# Processing Record 8 of Set 7 | qorveh
# Processing Record 9 of Set 7 | boyolangu
# Processing Record 10 of Set 7 | salzhemmendorf
# Processing Record 11 of Set 7 | mayumba
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | kaputa
# Processing Record 14 of Set 7 | mazamari
# Processing Record 15 of Set 7 | longyearbyen
# Processing Record 16 of Set 7 | coos bay
# Processing Record 17 of Set 7 | red bluff
# Processing Record 18 of Set 7 | dudinka
# Processing Record 19 of Set 7 | henties bay
# Processing Record 20 of Set 7 | wanaka
# Processing Record 21 of Set 7 | umea
# Processing Record 22 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 7 | kloulklubed
# Processing Record 24 of Set 7 | misratah
# Processing Record 25 of Set 7 | moron
# Processing Record 26 of Set 7 | san juan bautista
# Processing Record 27 of Set 7 | jawhar
# Processing Record 28 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 29 of Set 7 | torbay
# Processing Record 30 of Set 7 | zaraza
# Processing Record 31 of Set 7 | morehead
# Processing Record 32 of Set 7 | manadhoo
# Processing Record 33 of Set 7 | bowen
# Processing Record 34 of Set 7 | chicama
# Processing Record 35 of Set 7 | noumea
# Processing Record 36 of Set 7 | annau
# Processing Record 37 of Set 7 | lasa
# Processing Record 38 of Set 7 | huarmey
# Processing Record 39 of Set 7 | iguape
# Processing Record 40 of Set 7 | romano di lombardia
# Processing Record 41 of Set 7 | roshchino
# Processing Record 42 of Set 7 | tarrafal
# Processing Record 43 of Set 7 | lompoc
# Processing Record 44 of Set 7 | golden
# Processing Record 45 of Set 7 | oussouye
# Processing Record 46 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 7 | ca mau
# Processing Record 48 of Set 7 | anshun
# Processing Record 49 of Set 7 | port-gentil
# Processing Record 50 of Set 7 | benguela
# Processing Record 1 of Set 8 | ekhabi
# Processing Record 2 of Set 8 | jibuti
# Processing Record 3 of Set 8 | sinazongwe
# Processing Record 4 of Set 8 | beringovskiy
# Processing Record 5 of Set 8 | qui nhon
# Processing Record 6 of Set 8 | huancabamba
# Processing Record 7 of Set 8 | mbandaka
# Processing Record 8 of Set 8 | bud
# Processing Record 9 of Set 8 | shangrao
# Processing Record 10 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 8 | sao sebastiao
# Processing Record 12 of Set 8 | port lavaca
# Processing Record 13 of Set 8 | dogondoutchi
# Processing Record 14 of Set 8 | tokur
# Processing Record 15 of Set 8 | antofagasta
# Processing Record 16 of Set 8 | kudahuvadhoo
# Processing Record 17 of Set 8 | kysyl-syr
# Processing Record 18 of Set 8 | lexington
# Processing Record 19 of Set 8 | smolenka
# Processing Record 20 of Set 8 | valdivia
# Processing Record 21 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | kayerkan
# Processing Record 25 of Set 8 | vanimo
# Processing Record 26 of Set 8 | carahue
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | avera
# Processing Record 29 of Set 8 | evensk
# Processing Record 30 of Set 8 | tuatapere
# Processing Record 31 of Set 8 | hit
# Processing Record 32 of Set 8 | okha
# Processing Record 33 of Set 8 | garden city
# Processing Record 34 of Set 8 | batagay-alyta
# Processing Record 35 of Set 8 | kavieng
# Processing Record 36 of Set 8 | bambanglipuro
# Processing Record 37 of Set 8 | umm lajj
# Processing Record 38 of Set 8 | qinzhou
# Processing Record 39 of Set 8 | caravelas
# Processing Record 40 of Set 8 | ambulu
# Processing Record 41 of Set 8 | yokadouma
# Processing Record 42 of Set 8 | kodinsk
# Processing Record 43 of Set 8 | san quintin
# Processing Record 44 of Set 8 | zabid
# Processing Record 45 of Set 8 | hanmer springs
# Processing Record 46 of Set 8 | rocky mountain house
# Processing Record 47 of Set 8 | pacific grove
# Processing Record 48 of Set 8 | gizo
# Processing Record 49 of Set 8 | magadan
# Processing Record 50 of Set 8 | siva
# Processing Record 1 of Set 9 | kieta
# Processing Record 2 of Set 9 | islamkot
# Processing Record 3 of Set 9 | tateyama
# Processing Record 4 of Set 9 | olafsvik
# Processing Record 5 of Set 9 | gat
# Processing Record 6 of Set 9 | arlit
# Processing Record 7 of Set 9 | turinsk
# Processing Record 8 of Set 9 | tefe
# Processing Record 9 of Set 9 | chitungwiza
# Processing Record 10 of Set 9 | cayenne
# Processing Record 11 of Set 9 | dunedin
# Processing Record 12 of Set 9 | kurtamysh
# Processing Record 13 of Set 9 | bonthe
# Processing Record 14 of Set 9 | asosa
# Processing Record 15 of Set 9 | sarangani
# Processing Record 16 of Set 9 | vallenar
# Processing Record 17 of Set 9 | baruun-urt
# Processing Record 18 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 9 | manggar
# Processing Record 21 of Set 9 | bukene
# Processing Record 22 of Set 9 | praya
# Processing Record 23 of Set 9 | rize
# Processing Record 24 of Set 9 | zyryanskoye
# Processing Record 25 of Set 9 | la romana
# Processing Record 26 of Set 9 | talah
# City not found. Skipping...
# Processing Record 27 of Set 9 | zunyi
# Processing Record 28 of Set 9 | anaconda
# Processing Record 29 of Set 9 | hasaki
# Processing Record 30 of Set 9 | aksarka
# Processing Record 31 of Set 9 | bundibugyo
# Processing Record 32 of Set 9 | nacala
# Processing Record 33 of Set 9 | buguda
# Processing Record 34 of Set 9 | nishihara
# Processing Record 35 of Set 9 | carballo
# Processing Record 36 of Set 9 | hammerfest
# Processing Record 37 of Set 9 | marshall
# Processing Record 38 of Set 9 | ewa beach
# Processing Record 39 of Set 9 | puerto madero
# Processing Record 40 of Set 9 | birin
# Processing Record 41 of Set 9 | mizdah
# Processing Record 42 of Set 9 | yen bai
# Processing Record 43 of Set 9 | qasigiannguit
# Processing Record 44 of Set 9 | mbengwi
# Processing Record 45 of Set 9 | kidal
# Processing Record 46 of Set 9 | el porvenir
# Processing Record 47 of Set 9 | sakskobing
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | clovis
# Processing Record 50 of Set 9 | partizanskoye
# Processing Record 1 of Set 10 | okhotsk
# Processing Record 2 of Set 10 | sur
# Processing Record 3 of Set 10 | komsomolskiy
# Processing Record 4 of Set 10 | touros
# Processing Record 5 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 10 | olinda
# Processing Record 7 of Set 10 | ziro
# Processing Record 8 of Set 10 | grand gaube
# Processing Record 9 of Set 10 | auki
# Processing Record 10 of Set 10 | nyrob
# Processing Record 11 of Set 10 | marfino
# Processing Record 12 of Set 10 | whitley bay
# Processing Record 13 of Set 10 | bundaberg
# Processing Record 14 of Set 10 | axim
# Processing Record 15 of Set 10 | cairns
# Processing Record 16 of Set 10 | karakol
# Processing Record 17 of Set 10 | cascais
# Processing Record 18 of Set 10 | lima
# Processing Record 19 of Set 10 | berlevag
# Processing Record 20 of Set 10 | labuhan
# Processing Record 21 of Set 10 | oyama
# Processing Record 22 of Set 10 | nizwa
# Processing Record 23 of Set 10 | naze
# Processing Record 24 of Set 10 | hovd
# Processing Record 25 of Set 10 | pochutla
# Processing Record 26 of Set 10 | sira
# Processing Record 27 of Set 10 | irugur
# Processing Record 28 of Set 10 | meulaboh
# Processing Record 29 of Set 10 | mooi river
# City not found. Skipping...
# Processing Record 30 of Set 10 | broken hill
# Processing Record 31 of Set 10 | raga
# Processing Record 32 of Set 10 | marakkanam
# Processing Record 33 of Set 10 | bushenyi
# Processing Record 34 of Set 10 | faanui
# Processing Record 35 of Set 10 | uniontown
# Processing Record 36 of Set 10 | kasongo-lunda
# Processing Record 37 of Set 10 | awjilah
# Processing Record 38 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 39 of Set 10 | palmer
# Processing Record 40 of Set 10 | adrar
# Processing Record 41 of Set 10 | kampong chhnang
# Processing Record 42 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 43 of Set 10 | boljarovo
# City not found. Skipping...
# Processing Record 44 of Set 10 | waipawa
# Processing Record 45 of Set 10 | anahuac
# Processing Record 46 of Set 10 | dongobesh
# Processing Record 47 of Set 10 | nampula
# Processing Record 48 of Set 10 | kununurra
# Processing Record 49 of Set 10 | calolziocorte
# Processing Record 50 of Set 10 | birnin kebbi
# Processing Record 1 of Set 11 | sorland
# Processing Record 2 of Set 11 | shelabolikha
# Processing Record 3 of Set 11 | taoudenni
# Processing Record 4 of Set 11 | vao
# Processing Record 5 of Set 11 | tortoli
# Processing Record 6 of Set 11 | aksha
# Processing Record 7 of Set 11 | raichur
# Processing Record 8 of Set 11 | kelsterbach
# Processing Record 9 of Set 11 | najran
# Processing Record 10 of Set 11 | cookshire
# City not found. Skipping...
# Processing Record 11 of Set 11 | minatitlan
# Processing Record 12 of Set 11 | nieuw nickerie
# Processing Record 13 of Set 11 | opuwo
# Processing Record 14 of Set 11 | kem
# Processing Record 15 of Set 11 | izhma
# Processing Record 16 of Set 11 | road town
# Processing Record 17 of Set 11 | sungai besar
# Processing Record 18 of Set 11 | itoman
# Processing Record 19 of Set 11 | buala
# Processing Record 20 of Set 11 | margate
# Processing Record 21 of Set 11 | sretensk
# Processing Record 22 of Set 11 | sesheke
# Processing Record 23 of Set 11 | manbij
# Processing Record 24 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 11 | chernivtsi
# Processing Record 26 of Set 11 | taunggyi
# Processing Record 27 of Set 11 | south lake tahoe
# Processing Record 28 of Set 11 | sacramento
# Processing Record 29 of Set 11 | ajaccio
# Processing Record 30 of Set 11 | saint-joseph
# Processing Record 31 of Set 11 | harlingen
# Processing Record 32 of Set 11 | atar
# Processing Record 33 of Set 11 | klyuchi
# Processing Record 34 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 11 | mugango
# Processing Record 36 of Set 11 | requena
# Processing Record 37 of Set 11 | shakhtinsk
# Processing Record 38 of Set 11 | lakselv
# Processing Record 39 of Set 11 | kayankulam
# Processing Record 40 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 11 | los llanos de aridane
# Processing Record 42 of Set 11 | ardesen
# Processing Record 43 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 11 | trairi
# Processing Record 45 of Set 11 | tilichiki
# Processing Record 46 of Set 11 | belmonte
# Processing Record 47 of Set 11 | saveh
# Processing Record 48 of Set 11 | atocha
# Processing Record 49 of Set 11 | manosque
# Processing Record 50 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 12 | caranavi
# Processing Record 2 of Set 12 | celestun
# Processing Record 3 of Set 12 | iwanai
# Processing Record 4 of Set 12 | khovu-aksy
# Processing Record 5 of Set 12 | mambolo
# Processing Record 6 of Set 12 | angoche
# Processing Record 7 of Set 12 | kanigoro
# Processing Record 8 of Set 12 | lakes entrance
# Processing Record 9 of Set 12 | constitucion
# Processing Record 10 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 12 | genhe
# Processing Record 13 of Set 12 | awbari
# Processing Record 14 of Set 12 | bereda
# Processing Record 15 of Set 12 | asau
# Processing Record 16 of Set 12 | northam
# Processing Record 17 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 12 | ossora
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | sept-iles
# Processing Record 21 of Set 12 | elko
# Processing Record 22 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 12 | whitehorse
# Processing Record 24 of Set 12 | pitimbu
# Processing Record 25 of Set 12 | white rock
# Processing Record 26 of Set 12 | iquitos
# Processing Record 27 of Set 12 | kabo
# Processing Record 28 of Set 12 | chernyshevskiy
# Processing Record 29 of Set 12 | aktau
# Processing Record 30 of Set 12 | pout
# Processing Record 31 of Set 12 | acopiara
# Processing Record 32 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 12 | sechura
# Processing Record 34 of Set 12 | cloquet
# Processing Record 35 of Set 12 | pafos
# Processing Record 36 of Set 12 | santa fe
# Processing Record 37 of Set 12 | severomuysk
# Processing Record 38 of Set 12 | mount pleasant
# Processing Record 39 of Set 12 | weiser
# Processing Record 40 of Set 12 | yavatmal
# Processing Record 41 of Set 12 | sisimiut
# Processing Record 42 of Set 12 | toguchin
# Processing Record 43 of Set 12 | ambilobe
# Processing Record 44 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 12 | ibra
# Processing Record 46 of Set 12 | abha
# Processing Record 47 of Set 12 | iglesias
# Processing Record 48 of Set 12 | fukue
# Processing Record 49 of Set 12 | harpanahalli
# Processing Record 50 of Set 12 | yuanping
# Processing Record 1 of Set 13 | mgandu
# Processing Record 2 of Set 13 | sikasso
# Processing Record 3 of Set 13 | half moon bay
# Processing Record 4 of Set 13 | hirara
# Processing Record 5 of Set 13 | general roca
# Processing Record 6 of Set 13 | kabalo
# Processing Record 7 of Set 13 | el alto
# Processing Record 8 of Set 13 | puerto colombia
# Processing Record 9 of Set 13 | liwale
# Processing Record 10 of Set 13 | poum
# Processing Record 11 of Set 13 | xucheng
# Processing Record 12 of Set 13 | preobrazheniye
# Processing Record 13 of Set 13 | riyadh
# Processing Record 14 of Set 13 | mitsamiouli
# Processing Record 15 of Set 13 | cacoal
# Processing Record 16 of Set 13 | west wendover
# Processing Record 17 of Set 13 | zhezkazgan
# Processing Record 18 of Set 13 | aitape
# Processing Record 19 of Set 13 | samarai
# Processing Record 20 of Set 13 | christchurch
# Processing Record 21 of Set 13 | ahmadnagar
# Processing Record 22 of Set 13 | shasta lake
# Processing Record 23 of Set 13 | ampanihy
# Processing Record 24 of Set 13 | parras
# City not found. Skipping...
# Processing Record 25 of Set 13 | marsa matruh
# Processing Record 26 of Set 13 | ancona
# Processing Record 27 of Set 13 | petrodvorets
# Processing Record 28 of Set 13 | trofors
# Processing Record 29 of Set 13 | kutum
# Processing Record 30 of Set 13 | lodja
# Processing Record 31 of Set 13 | tessalit
# Processing Record 32 of Set 13 | ndiekro
# City not found. Skipping...
# Processing Record 33 of Set 13 | quatre cocos
# Processing Record 34 of Set 13 | lamu
# Processing Record 35 of Set 13 | yecuatla
# Processing Record 36 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 13 | aranos
# Processing Record 38 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 13 | hitoyoshi
# Processing Record 40 of Set 13 | hayden
# Processing Record 41 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 13 | ocotal
# Processing Record 43 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 13 | santiago
# Processing Record 45 of Set 13 | inta
# Processing Record 46 of Set 13 | pervomaysk
# Processing Record 47 of Set 13 | chaplygin
# Processing Record 48 of Set 13 | along
# Processing Record 49 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 13 | ayan
# Processing Record 1 of Set 14 | gueugnon
# Processing Record 2 of Set 14 | ancud
# Processing Record 3 of Set 14 | auray
# Processing Record 4 of Set 14 | luena
# Processing Record 5 of Set 14 | soe
# Processing Record 6 of Set 14 | saint-georges
# Processing Record 7 of Set 14 | dingtao
# Processing Record 8 of Set 14 | revda
# Processing Record 9 of Set 14 | trinidad
# Processing Record 10 of Set 14 | adelaide
# Processing Record 11 of Set 14 | bilibino
# Processing Record 12 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 13 of Set 14 | lata
# Processing Record 14 of Set 14 | beloha
# Processing Record 15 of Set 14 | comodoro rivadavia
# Processing Record 16 of Set 14 | richmond
# Processing Record 17 of Set 14 | humboldt
# Processing Record 18 of Set 14 | gari
# Processing Record 19 of Set 14 | massaguet
# Processing Record 20 of Set 14 | bairiki
# Processing Record 21 of Set 14 | chara
# Processing Record 22 of Set 14 | luang prabang
# Processing Record 23 of Set 14 | bethanien
# Processing Record 24 of Set 14 | mikun
# Processing Record 25 of Set 14 | lang son
# Processing Record 26 of Set 14 | fallon
# Processing Record 27 of Set 14 | greymouth
# Processing Record 28 of Set 14 | presidencia roque saenz pena
# Processing Record 29 of Set 14 | russellville
# Processing Record 30 of Set 14 | maasin
# Processing Record 31 of Set 14 | srivardhan
# Processing Record 32 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 14 | verkhnevilyuysk
# Processing Record 34 of Set 14 | pokhara
# Processing Record 35 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 14 | xining
# Processing Record 37 of Set 14 | paranavai
# Processing Record 38 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 14 | rudnogorsk
# Processing Record 40 of Set 14 | kasongo
# Processing Record 41 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 42 of Set 14 | bandar-e lengeh
# Processing Record 43 of Set 14 | udachnyy
# Processing Record 44 of Set 14 | ketchikan
# Processing Record 45 of Set 14 | la ronge
# Processing Record 46 of Set 14 | bilma
# Processing Record 47 of Set 14 | kanniyakumari
# Processing Record 48 of Set 14 | stephenville
# Processing Record 49 of Set 14 | saint-dizier
# Processing Record 50 of Set 14 | pital
# Processing Record 1 of Set 15 | guerrero negro
# Processing Record 2 of Set 15 | pangnirtung
# Processing Record 3 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 15 | new plymouth
# Processing Record 5 of Set 15 | evanston
# Processing Record 6 of Set 15 | jeremie
# Processing Record 7 of Set 15 | sombor
# Processing Record 8 of Set 15 | mezimesti
# Processing Record 9 of Set 15 | kirakira
# Processing Record 10 of Set 15 | gambela
# Processing Record 11 of Set 15 | garlasco
# Processing Record 12 of Set 15 | bima
# Processing Record 13 of Set 15 | tatawin
# Processing Record 14 of Set 15 | amberley
# Processing Record 15 of Set 15 | bayangol
# Processing Record 16 of Set 15 | santa rosa
# Processing Record 17 of Set 15 | rabat
# Processing Record 18 of Set 15 | padang
# Processing Record 19 of Set 15 | belaya gora
# Processing Record 20 of Set 15 | porto novo
# Processing Record 21 of Set 15 | plouzane
# Processing Record 22 of Set 15 | bermejo
# Processing Record 23 of Set 15 | maragogi
# Processing Record 24 of Set 15 | demyanovo
# Processing Record 25 of Set 15 | san ramon
# Processing Record 26 of Set 15 | labytnangi
# Processing Record 27 of Set 15 | ongandjera
# Processing Record 28 of Set 15 | albanel
# Processing Record 29 of Set 15 | mehamn
# Processing Record 30 of Set 15 | pangody
# Processing Record 31 of Set 15 | yakeshi
# Processing Record 32 of Set 15 | winneba
# Processing Record 33 of Set 15 | isangel
# Processing Record 34 of Set 15 | bodden town
# Processing Record 35 of Set 15 | pandan
# Processing Record 36 of Set 15 | inirida
# Processing Record 37 of Set 15 | ouadda
# Processing Record 38 of Set 15 | shemonaikha
# Processing Record 39 of Set 15 | bat khela
# Processing Record 40 of Set 15 | thamaga
# Processing Record 41 of Set 15 | brae
# Processing Record 42 of Set 15 | le vauclin
# Processing Record 43 of Set 15 | gladstone
# Processing Record 44 of Set 15 | nador
# Processing Record 45 of Set 15 | broome
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description" ]
city_data_df = city_data_df[new_column_order]

city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#          City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Jamestown      US   42.10   -79.24     71.71        65           0
# 1       Kapaa      US   22.08  -159.32     84.18        71          20
# 2   Ostrovnoy      RU   68.05    39.51     51.10        84           9
# 3     Rikitea      PF  -23.12  -134.97     72.70        73          63
# 4      Atuona      PF   -9.80  -139.03     76.98        72          24
# 5    Zhigansk      RU   66.77   123.37     51.66        66          65
# 6      Otuzco      PE   -7.90   -78.58     51.69        69          79
# 7  Dzerzhinsk      RU   56.24    43.46     53.42       100           0
# 8  Port Blair      IN   11.67    92.75     81.46        81         100
# 9      Dikson      RU   73.51    80.55     43.86        92          87
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1       17.27          few clouds
# 2       17.13           clear sky
# 3       19.84       broken clouds
# 4       24.65          few clouds
# 5       23.51       broken clouds
# 6        1.30       broken clouds
# 7        0.00           clear sky
# 8       15.57     overcast clouds
# 9       19.55     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
